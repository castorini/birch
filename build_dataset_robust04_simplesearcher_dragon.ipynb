# %%
import shlex
import subprocess
import sys
import json
from tqdm import tqdm
import string

import jnius_config

# target_old: lucene6 for thesis
# target_old: lucene7 
jnius_config.set_classpath("target/anserini-0.4.1-SNAPSHOT-fatjar.jar")

from jnius import autoclass
JString = autoclass('java.lang.String')
JSearcher = autoclass('io.anserini.search.SimpleSearcher')

searcher = JSearcher(JString('./lucene-index.robust04.pos+docvectors+rawdocs'))

# %% [markdown]
# ## 5-folds test on Robust04

# %%
def cal_score_new(fn_qrels="src/main/resources/topics-and-qrels/qrels.robust2004.txt", prediction="score.txt"):
    cmd = "/bin/sh run_eval_new.sh {} {}".format(prediction, fn_qrels)
    pargs = shlex.split(cmd)
    p = subprocess.Popen(pargs, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    pout, perr = p.communicate()
    print("running {}".format(cmd))
    if sys.version_info[0] < 3:
        lines = pout.split('\n')
    else:
        lines = pout.split(b'\n')
    Map = float(lines[0].strip().split()[-1])
    Mrr = float(lines[1].strip().split()[-1])
    P20 = float(lines[2].strip().split()[-1])
    P30 = float(lines[3].strip().split()[-1])
    NDCG20 = float(lines[4].strip().split()[-1])
    print(Map)
    print(Mrr)
    print(P30)
    print(P20)
    print(NDCG20)
    return Map, Mrr, P30, P20, NDCG20


def get_qid2reldocids(fqrel):
    f = open(fqrel)
    qid2reldocids = {}
    for l in f:
        qid, _, docid, score = l.replace("\n", "").strip().split()
        if int(score) > 0:
            if qid not in qid2reldocids:
                qid2reldocids[qid] = set()
            qid2reldocids[qid].add(docid)
    return qid2reldocids

def search_new(searcher, prediction_fn, qid2text, output_fn, qid2reldocids, K=1000):
    f = open(prediction_fn, "w")
    out = open(output_fn, "w")
    for qid in qid2text:
        a = qid2text[qid]
        hits = searcher.search(JString(a), K)
        for i in range(len(hits)):
            sim = hits[i].score
            docno = hits[i].docid
            label = 1 if qid in qid2reldocids and docno in qid2reldocids[qid] else 0
            b = parse_doc_from_index(hits[i].content)
            f.write("{} 0 {} 0 {} {}\n".format(qid, docno, sim, method))
            out.write("{}\t{}\t{}\t{}\t{}\t{}\n".format(label, a, b, qid, docno, sim))
            out.flush()
    f.close()
    out.close()
    
def get_qid2text_new(data):
    qid2text = {}
    for d in data['questions']:
        qid2text[d["id"]] = d["body"]
    return qid2text


def parse_doc_from_index(content):
    ls = content.split("\n")
    see_text = False
    doc = ""
    for l in ls:
        l = l.replace("\n", "").strip()
        if "<TEXT>" in l:
            see_text = True
        elif "</TEXT>" in l:
            break
        elif see_text:
            if l == "<P>" or l == "</P>":
                continue
            doc += l + " "
    return doc.strip()

# %%
fqrel = "src/main/resources/topics-and-qrels/qrels.robust2004.txt"
qid2reldocids = get_qid2reldocids(fqrel)

# %%
# BM25 + RM3
# best_rm3_parameters = [[45, 8, 0.2], [45, 6, 0.3], [50, 10, 0.2], [50, 12, 0.2], [45, 8, 0.2]]
best_rm3_parameters = [[47, 9, 0.3], [47, 9, 0.3], [47, 9, 0.3], [47, 9, 0.3], [26, 8, 0.3]]
for split in range(1, 6):
    ftrain = json.load(open("src/main/resources/fine_tuning/drr_folds/rob04.train.s{}.json".format(split)))
    fdev = json.load(open("src/main/resources/fine_tuning/drr_folds/rob04.dev.s{}.json".format(split)))
    ftest = json.load(open("src/main/resources/fine_tuning/drr_folds/rob04.test.s{}.json".format(split)))
    for mode, data in [("train", ftrain), ("dev", fdev), ("test", ftest)]: #  
        qid2text = get_qid2text_new(data)
        method = "BM25_0.9_0.5_RM3_{}_{}_{}".format(*best_rm3_parameters[split-1])
        prediction_fn = "predictions_tuned/predict_{}_robust04_split{}_{}.txt".format(method, split, mode)
        output_fn = "src/main/python/rerank/MatchZoo/data/robust04/Robust04Corpus/split{}_{}_{}.txt".format(split, mode, method)
        searcher.setBM25Similarity(0.9, 0.5)
        searcher.setRM3Reranker(*best_rm3_parameters[split-1])
        search_new(searcher, prediction_fn, qid2text, output_fn, qid2reldocids)
        cal_score_new(prediction=prediction_fn)
        print()
# Out:
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_RM3_47_9_0.3_robust04_split1_train.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.3089
# 0.6565
# 0.3578
# 0.4017
# 0.4526
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_RM3_47_9_0.3_robust04_split1_dev.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.295
# 0.725
# 0.3401
# 0.3786
# 0.4397
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_RM3_47_9_0.3_robust04_split1_test.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.307
# 0.6597
# 0.3493
# 0.407
# 0.4645
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_RM3_47_9_0.3_robust04_split2_train.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.3304
# 0.6822
# 0.3724
# 0.4267
# 0.4737
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_RM3_47_9_0.3_robust04_split2_dev.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2425
# 0.5827
# 0.3053
# 0.332
# 0.4012
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_RM3_47_9_0.3_robust04_split2_test.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.295
# 0.725
# 0.3401
# 0.3786
# 0.4397
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_RM3_47_9_0.3_robust04_split3_train.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.3145
# 0.7035
# 0.3633
# 0.4121
# 0.47
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_RM3_47_9_0.3_robust04_split3_dev.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.3432
# 0.6607
# 0.368
# 0.423
# 0.4514
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_RM3_47_9_0.3_robust04_split3_test.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2425
# 0.5827
# 0.3053
# 0.332
# 0.4012
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_RM3_47_9_0.3_robust04_split4_train.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2814
# 0.6554
# 0.3315
# 0.3725
# 0.4351
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_RM3_47_9_0.3_robust04_split4_dev.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.3411
# 0.7261
# 0.4
# 0.45
# 0.5051
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_RM3_47_9_0.3_robust04_split4_test.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.3432
# 0.6607
# 0.368
# 0.423
# 0.4514
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_RM3_26_8_0.3_robust04_split5_train.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2944
# 0.6571
# 0.3414
# 0.3839
# 0.4365
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_RM3_26_8_0.3_robust04_split5_dev.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.3057
# 0.6639
# 0.3427
# 0.388
# 0.4504
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_RM3_26_8_0.3_robust04_split5_test.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.3288
# 0.7161
# 0.384
# 0.446
# 0.5

# %%
# BM25
for split in range(1, 6):
    ftrain = json.load(open("src/main/resources/fine_tuning/drr_folds/rob04.train.s{}.json".format(split)))
    fdev = json.load(open("src/main/resources/fine_tuning/drr_folds/rob04.dev.s{}.json".format(split)))
    ftest = json.load(open("src/main/resources/fine_tuning/drr_folds/rob04.test.s{}.json".format(split)))
    for mode, data in [("test", ftest), ("train", ftrain), ("dev", fdev)]: #  
        qid2text = get_qid2text_new(data)
        method = "BM25_0.9_0.5"
        prediction_fn = "predictions_tuned/predict_{}_robust04_split{}_{}.txt".format(method, split, mode)
        output_fn = "src/main/python/rerank/MatchZoo/data/robust04/Robust04Corpus/split{}_{}_{}.txt".format(split, mode, method)
        searcher.setBM25Similarity(0.9, 0.5)
        searcher.setDefaultReranker()
        search_new(searcher, prediction_fn, qid2text, output_fn, qid2reldocids)
        cal_score_new(prediction=prediction_fn)
        print()
# Out:
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_robust04_split1_test.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2669
# 0.6443
# 0.3147
# 0.362
# 0.4313
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_robust04_split1_train.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2528
# 0.7068
# 0.3136
# 0.3683
# 0.4293
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_robust04_split1_dev.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2323
# 0.6562
# 0.3007
# 0.3388
# 0.3943
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_robust04_split2_test.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2323
# 0.6562
# 0.3007
# 0.3388
# 0.3943
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_robust04_split2_train.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2703
# 0.7011
# 0.3211
# 0.3783
# 0.4377
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_robust04_split2_dev.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2144
# 0.6615
# 0.292
# 0.332
# 0.4059
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_robust04_split3_test.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2144
# 0.6615
# 0.292
# 0.332
# 0.4059
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_robust04_split3_train.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2553
# 0.6761
# 0.3163
# 0.3648
# 0.426
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_robust04_split3_dev.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2778
# 0.7314
# 0.3153
# 0.38
# 0.4302
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_robust04_split4_test.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2778
# 0.7314
# 0.3153
# 0.38
# 0.4302
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_robust04_split4_train.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2379
# 0.654
# 0.3025
# 0.3443
# 0.4106
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_robust04_split4_dev.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2661
# 0.7275
# 0.3333
# 0.393
# 0.4517
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_robust04_split5_test.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2661
# 0.7275
# 0.3333
# 0.393
# 0.4517
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_robust04_split5_train.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2415
# 0.6832
# 0.3027
# 0.3503
# 0.4102
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_robust04_split5_dev.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2669
# 0.6443
# 0.3147
# 0.362
# 0.4313

# %%
# QL + RM3
best_rm3_parameters = [[45, 8, 0.2], [45, 6, 0.3], [50, 10, 0.2], [50, 12, 0.2], [45, 8, 0.2]]

for split in range(1, 6):
    ftrain = json.load(open("src/main/resources/fine_tuning/drr_folds/rob04.train.s{}.json".format(split)))
    fdev = json.load(open("src/main/resources/fine_tuning/drr_folds/rob04.dev.s{}.json".format(split)))
    ftest = json.load(open("src/main/resources/fine_tuning/drr_folds/rob04.test.s{}.json".format(split)))
    for mode, data in [("train", ftrain), ("dev", fdev), ("test", ftest)]: # 
        qid2text = get_qid2text_new(data)
        method = "QL_1000_RM3_{}_{}_{}".format(*best_rm3_parameters[split-1])
        prediction_fn = "predictions_tuned/predict_{}_robust04_split{}_{}.txt".format(method, split, mode)
        output_fn = "src/main/python/rerank/MatchZoo/data/robust04/Robust04Corpus/split{}_{}_{}.txt".format(split, mode, method)
        searcher.setLMDirichletSimilarity(1000)
        searcher.setRM3Reranker(*best_rm3_parameters[split-1])
        search_new(searcher, prediction_fn, qid2text, output_fn, qid2reldocids)
        cal_score_new(prediction=prediction_fn)
        print()

# %%
# QL
for split in range(1, 6):
    ftrain = json.load(open("src/main/resources/fine_tuning/drr_folds/rob04.train.s{}.json".format(split)))
    fdev = json.load(open("src/main/resources/fine_tuning/drr_folds/rob04.dev.s{}.json".format(split)))
    ftest = json.load(open("src/main/resources/fine_tuning/drr_folds/rob04.test.s{}.json".format(split)))
    for mode, data in [("train", ftrain), ("dev", fdev), ("test", ftest)]: # 
        qid2text = get_qid2text_new(data)
        method = "QL_1000".format()
        prediction_fn = "predictions_tuned/predict_{}_robust04_split{}_{}.txt".format(method, split, mode)
        output_fn = "src/main/python/rerank/MatchZoo/data/robust04/Robust04Corpus/split{}_{}.txt".format(split, mode)
        searcher.setLMDirichletSimilarity(1000.0)
        searcher.setDefaultReranker()
        search_new(searcher, prediction_fn, qid2text, output_fn, qid2reldocids)
        cal_score_new(prediction=prediction_fn)
        print()
# Out:
# running /bin/sh run_eval_new.sh predictions_tuned/predict_QL_1000_robust04_split1_train.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2486
# 0.6999
# 0.3147
# 0.3587
# 0.4182
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_QL_1000_robust04_split1_dev.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2175
# 0.6579
# 0.2769
# 0.3122
# 0.3677
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_QL_1000_robust04_split1_test.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2696
# 0.6607
# 0.318
# 0.365
# 0.4334
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_QL_1000_robust04_split2_train.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2712
# 0.7149
# 0.3276
# 0.376
# 0.4347
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_QL_1000_robust04_split2_dev.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2019
# 0.6158
# 0.2793
# 0.313
# 0.384
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_QL_1000_robust04_split2_test.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2175
# 0.6579
# 0.2769
# 0.3122
# 0.3677
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_QL_1000_robust04_split3_train.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2525
# 0.6877
# 0.3096
# 0.3544
# 0.4165
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_QL_1000_robust04_split3_dev.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2743
# 0.7402
# 0.3313
# 0.378
# 0.4233
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_QL_1000_robust04_split3_test.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2019
# 0.6158
# 0.2793
# 0.313
# 0.384
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_QL_1000_robust04_split4_train.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2297
# 0.6447
# 0.2915
# 0.3302
# 0.3952
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_QL_1000_robust04_split4_dev.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2697
# 0.7437
# 0.3333
# 0.385
# 0.4474
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_QL_1000_robust04_split4_test.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2743
# 0.7402
# 0.3313
# 0.378
# 0.4233
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_QL_1000_robust04_split5_train.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2313
# 0.6714
# 0.296
# 0.3346
# 0.3918
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_QL_1000_robust04_split5_dev.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2696
# 0.6607
# 0.318
# 0.365
# 0.4334
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_QL_1000_robust04_split5_test.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2697
# 0.7437
# 0.3333
# 0.385
# 0.4474

# %% [markdown]
# ## 2-folds test on Robust04

# %%
def get_qid2text(fn, qid2text, split):
    qid_fold0, qid_fold1 = json.load(open(fn))
    if split == 0:
        train_num = int(len(qid_fold0)*0.8)
        qids_train = qid_fold0[:train_num]
        qids_dev = qid_fold0[train_num:]
        qids_test = qid_fold1
    else:
        train_num = int(len(qid_fold1)*0.8)
        qids_train = qid_fold1[:train_num]
        qids_dev = qid_fold1[train_num:]
        qids_test = qid_fold0
    qid2text_train = {qid: qid2text[qid] for qid in qids_train}
    qid2text_dev = {qid: qid2text[qid] for qid in qids_dev}
    qid2text_test = {qid: qid2text[qid] for qid in qids_test}
    return qid2text_train, qid2text_dev, qid2text_test

def get_qid2query(ftopic):
    qid2query = {}
    f = open(ftopic)
    query_tag = "title"
    empty = False
    for l in f:
        if empty == True:
            qid2query[qid] = l.replace("\n", "").strip()
            empty = False
        ind = l.find("Number: ")
        if ind >= 0:
            qid = l[ind+8:-1]
            qid = str(int(qid))
        ind = l.find("<{}>".format(query_tag))
        if ind >= 0:
            query = l[ind+8:-1].strip()
            if len(query) == 0:
                empty = True
            else:
                qid2query[qid] = query
    return qid2query

# fqrel = "src/main/resources/topics-and-qrels/qrels.robust2004.txt"
# qid2reldocids = get_qid2reldocids(fqrel)

# %%
# BM25
ftopic = "src/main/resources/topics-and-qrels/topics.robust04.301-450.601-700.txt"
qid2text_all = get_qid2query(ftopic)
for split in range(2):
    qids_train, qids_dev, qids_test = get_qid2text("src/main/resources/fine_tuning/robust04-paper1-folds.json",\
                                                   qid2text_all, split)
    for mode, qid2text in [("train", qids_train), ("dev", qids_dev), ("test", qids_test)]: #  
        method = "BM25_0.9_0.5"
        prediction_fn = "predictions_tuned/predict_{}_robust04_split{}_{}.txt".format(method, split, mode)
        output_fn = "src/main/python/rerank/MatchZoo/data/robust04/Robust04Corpus/split{}_2fold_{}_{}.txt".format(split, mode, method)
        searcher.setBM25Similarity(0.9, 0.5)
        searcher.setDefaultReranker()
        search_new(searcher, prediction_fn, qid2text, output_fn, qid2reldocids)
        cal_score_new(prediction=prediction_fn)
        print()
# Out:
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_robust04_split0_train.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2557
# 0.6747
# 0.2967
# 0.3355
# 0.4175
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_robust04_split0_dev.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2548
# 0.7325
# 0.2958
# 0.3583
# 0.4031
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_robust04_split0_test.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2477
# 0.6827
# 0.3259
# 0.3824
# 0.4308
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_robust04_split1_train.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2299
# 0.6651
# 0.3267
# 0.385
# 0.4281
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_robust04_split1_dev.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.3187
# 0.7532
# 0.3227
# 0.372
# 0.4417
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_robust04_split1_test.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2555
# 0.6859
# 0.2965
# 0.3399
# 0.4148

# %%
# BM25+RM3
best_rm3_parameters = [[26, 8, 0.3], [50, 17, 0.2]]
ftopic = "src/main/resources/topics-and-qrels/topics.robust04.301-450.601-700.txt"
qid2text_all = get_qid2query(ftopic)
for split in range(2):
    qids_train, qids_dev, qids_test = get_qid2text("src/main/resources/fine_tuning/robust04-paper1-folds.json",\
                                                   qid2text_all, split)
    for mode, qid2text in [("train", qids_train), ("dev", qids_dev), ("test", qids_test)]: #  
        method = "BM25_0.9_0.5_RM3_{}_{}_{}".format(*best_rm3_parameters[split])
        prediction_fn = "predictions_tuned/predict_{}_robust04_split{}_{}.txt".format(method, split, mode)
        output_fn = "src/main/python/rerank/MatchZoo/data/robust04/Robust04Corpus/split{}_2fold_{}_{}.txt".format(split, mode, method)
        searcher.setBM25Similarity(0.9, 0.5)
        searcher.setRM3Reranker(*best_rm3_parameters[split])
        search_new(searcher, prediction_fn, qid2text, output_fn, qid2reldocids)
        cal_score_new(prediction=prediction_fn)
        print()
# Out:
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_RM3_26_8_0.3_robust04_split0_train.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.3005
# 0.6804
# 0.34
# 0.3825
# 0.4556
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_RM3_26_8_0.3_robust04_split0_dev.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.3596
# 0.7213
# 0.3819
# 0.4396
# 0.4819
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_RM3_26_8_0.3_robust04_split0_test.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2953
# 0.6525
# 0.3523
# 0.4008
# 0.4434
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_RM3_50_17_0.2_robust04_split1_train.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.2875
# 0.6463
# 0.3663
# 0.415
# 0.4532
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_RM3_50_17_0.2_robust04_split1_dev.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.3595
# 0.7182
# 0.3467
# 0.402
# 0.4516
#
# running /bin/sh run_eval_new.sh predictions_tuned/predict_BM25_0.9_0.5_RM3_50_17_0.2_robust04_split1_test.txt src/main/resources/topics-and-qrels/qrels.robust2004.txt
# 0.3021
# 0.6507
# 0.3384
# 0.3734
# 0.4362

# %%
qids_test
# Out:
# {'302': 'Poliomyelitis and Post-Polio',
#  '304': 'Endangered Species (Mammals)',
#  '306': 'African Civilian Deaths',
#  '308': 'Implant Dentistry',
#  '310': 'Radio Waves and Brain Cancer',
#  '312': 'Hydroponics',
#  '314': 'Marine Vegetation',
#  '316': 'Polygamy Polyandry Polygyny',
#  '318': 'Best Retirement Country',
#  '320': 'Undersea Fiber Optic Cable',
#  '322': 'International Art Crime',
#  '324': 'Argentine/British Relations',
#  '326': 'Ferry Sinkings',
#  '328': 'Pope Beatifications',
#  '330': 'Iran-Iraq Cooperation',
#  '332': 'Income Tax Evasion',
#  '334': 'Export Controls Cryptography',
#  '336': 'Black Bear Attacks',
#  '338': 'Risk of Aspirin',
#  '340': 'Land Mine Ban',
#  '342': 'Diplomatic Expulsion',
#  '344': 'Abuses of E-Mail',
#  '346': 'Educational Standards',
#  '348': 'Agoraphobia',
#  '350': 'Health and Computer Terminals',
#  '352': 'British Chunnel impact',
#  '354': 'journalist risks',
#  '356': 'postmenopausal estrogen Britain',
#  '358': 'blood-alcohol fatalities',
#  '360': 'drug legalization benefits',
#  '362': 'human smuggling',
#  '364': 'rabies',
#  '366': 'commercial cyanide uses',
#  '368': 'in vitro fertilization',
#  '370': 'food/drug laws',
#  '372': 'Native American casino',
#  '374': 'Nobel prize winners',
#  '376': 'World Court',
#  '378': 'euro opposition',
#  '380': 'obesity medical treatment',
#  '382': 'hydrogen fuel automobiles',
#  '384': 'space station moon',
#  '386': 'teaching disabled children',
#  '388': 'organic soil enhancement',
#  '390': 'orphan drugs',
#  '392': 'robotics',
#  '394': 'home schooling',
#  '396': 'sick building syndrome',
#  '398': "dismantling Europe's arsenal",
#  '400': 'Amazon rain forest',
#  '402': 'behavioral genetics',
#  '404': 'Ireland, peace talks',
#  '406': "Parkinson's disease",
#  '408': 'tropical storms',
#  '410': 'Schengen agreement',
#  '412': 'airport security',
#  '414': 'Cuba, sugar, exports',
#  '416': 'Three Gorges Project',
#  '418': 'quilts, income',
#  '420': 'carbon monoxide poisoning',
#  '422': 'art, stolen, forged',
#  '424': 'suicides',
#  '426': 'law enforcement, dogs',
#  '428': 'declining birth rates',
#  '430': 'killer bee attacks',
#  '432': 'profiling, motorists, police',
#  '434': 'Estonia, economy',
#  '436': 'railway accidents',
#  '438': 'tourism, increase',
#  '440': 'child labor',
#  '442': 'heroic acts',
#  '444': 'supercritical fluids',
#  '446': 'tourists, violence',
#  '448': 'ship losses',
#  '450': 'King Hussein, peace',
#  '602': 'Czech, Slovak sovereignty',
#  '604': 'Lyme disease arthritis',
#  '606': 'leg traps ban',
#  '608': 'taxing social security',
#  '610': 'minimum wage adverse impact',
#  '612': 'Tibet protesters',
#  '614': 'Flavr Savr tomato',
#  '616': 'Volkswagen Mexico',
#  '618': 'Ayatollah Khomeini death',
#  '620': 'France nuclear testing',
#  '622': 'price fixing',
#  '624': 'SDI Star Wars',
#  '626': 'human stampede',
#  '628': 'U.S. invasion of Panama',
#  '630': 'Gulf War Syndrome',
#  '632': 'southeast Asia tin mining',
#  '634': 'L-tryptophan deaths',
#  '636': 'jury duty exemptions',
#  '638': 'wrongful convictions',
#  '640': 'maternity leave policies',
#  '642': 'Tiananmen Square protesters',
#  '644': 'exotic animals import',
#  '646': 'food stamps increase',
#  '648': 'family leave law',
#  '650': 'tax evasion indicted',
#  '652': 'OIC Balkans 1990s',
#  '654': 'same-sex schools',
#  '656': 'lead poisoning children',
#  '658': 'teenage pregnancy',
#  '660': 'whale watching California',
#  '662': 'telemarketer protection',
#  '664': 'American Indian Museum',
#  '666': 'Thatcher resignation impact',
#  '668': 'poverty, disease',
#  '670': 'U.S. elections apathy',
#  '672': 'NRA membership profile',
#  '674': 'Greenpeace prosecuted',
#  '676': 'poppy cultivation',
#  '678': 'joint custody impact',
#  '680': 'immigrants Spanish school',
#  '682': 'adult immigrants English',
#  '684': 'part-time benefits',
#  '686': 'Argentina pegging dollar',
#  '688': 'non-U.S. media bias',
#  '690': 'college education advantage',
#  '692': 'prostate cancer detection treatment',
#  '694': 'compost pile',
#  '696': 'safety plastic surgery',
#  '698': 'literacy rates Africa',
#  '700': 'gasoline tax U.S.'}
